# %%
import pandas as pd

# %%
df_rua = pd.read_csv('/content/rua_clean_v1.csv')

# %%
df_rua
# Out:
#       CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n  Unnamed: 1  \
# 0                                  1 of 10346         NaN
# 1                                  1 of 10346         NaN
# 2                                  1 of 10346         NaN
# 3                                  1 of 10346         NaN
# 4                                  1 of 10346         NaN
# ...                                       ...         ...
# 99858                              1 of 10346         NaN
# 99859                              1 of 10346         NaN
# 99860                              1 of 10346         NaN
# 99861                              1 of 10346         NaN
# 99862                              1 of 10346         NaN
#
#                                      Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                                           NaN         NaN         NaN
# 1                                           NaN         NaN         NaN
# 2                                    NEW ANTRIM         NaN         NaN
# 3                         "F","FILE993","Z","D"         NaN         NaN
# 4                                    NEW ANTRIM         NaN         NaN
# ...                                         ...         ...         ...
# 99858                                NEW ANTRIM         NaN         NaN
# 99859  REG           31-12-2023 05:24    000003         NaN         NaN
# 99860                                    Inline         NaN         NaN
# 99861                                   Receive         NaN         NaN
# 99862                                                   NaN         NaN
#
#              Unnamed: 5  Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0      Journal log list         NaN       Date:  04/06/2024
# 1      Journal log list         NaN       Date:  04/06/2024
# 2      Journal log list         NaN       Date:  04/06/2024
# 3      Journal log list         NaN       Date:  04/06/2024
# 4      Journal log list         NaN       Date:  04/06/2024
# ...                 ...         ...         ...         ...
# 99858  Journal log list         NaN       Date:  04/06/2024
# 99859  Journal log list         NaN       Date:  04/06/2024
# 99860  Journal log list         NaN       Date:  04/06/2024
# 99861  Journal log list         NaN       Date:  04/06/2024
# 99862  Journal log list         NaN       Date:  04/06/2024
#
# [99863 rows x 9 columns]

# %%
df_rua.iloc[275:300]
# Out:
#     CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n  Unnamed: 1  \
# 275                              1 of 10346         NaN
# 276                              1 of 10346         NaN
# 277                              1 of 10346         NaN
# 278                              1 of 10346         NaN
# 279                              1 of 10346         NaN
# 280                              1 of 10346         NaN
# 281                              1 of 10346         NaN
# 282                              1 of 10346         NaN
# 283                              1 of 10346         NaN
# 284                              1 of 10346         NaN
# 285                              1 of 10346         NaN
# 286                              1 of 10346         NaN
# 287                              1 of 10346         NaN
# 288                              1 of 10346         NaN
# 289                              1 of 10346         NaN
# 290                              1 of 10346         NaN
# 291                              1 of 10346         NaN
# 292                              1 of 10346         NaN
# 293                              1 of 10346         NaN
# 294                              1 of 10346         NaN
# 295                              1 of 10346         NaN
# 296                              1 of 10346         NaN
# 297                              1 of 10346         NaN
# 298                              1 of 10346         NaN
# 299                              1 of 10346         NaN
#
#                                    Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 275         1  PTN TOAST                €1.75         NaN         NaN
# 276         1  HOT CHOC                 €3.70         NaN         NaN
# 277            SUBTOTAL                €36.30         NaN         NaN
# 278         1  APPLE JUICE SM           €2.95         NaN         NaN
# 279         1  LATTE                    €3.80         NaN         NaN
# 280                                      9 No         NaN         NaN
# 281            EX VAT @ 13.5%          €10.67         NaN         NaN
# 282                                       NaN         NaN         NaN
# 283                                       NaN         NaN         NaN
# 284                                NEW ANTRIM         NaN         NaN
# 285  REG  SINEAD   03-01-2023 15:05    000278         NaN         NaN
# 286                                NEW ANTRIM         NaN         NaN
# 287  REG  SINEAD   03-01-2023 15:05    000279         NaN         NaN
# 288            SHOW  TABLES                 2         NaN         NaN
# 289         1  CHK TSD                 €11.50         NaN         NaN
# 290                                   SAUTEED         NaN         NaN
# 291                                       NaN         NaN         NaN
# 292                                       NaN         NaN         NaN
# 293                                       NaN         NaN         NaN
# 294            _C_H_A_N_G_E             €5.50         NaN         NaN
# 295                                NEW ANTRIM         NaN         NaN
# 296  REG  SINEAD   03-01-2023 15:14    000289         NaN         NaN
# 297                                NEW ANTRIM         NaN         NaN
# 298  REG  SINEAD   03-01-2023 15:14    000290         NaN         NaN
# 299            SHOW  TABLES                 1         NaN         NaN
#
#            Unnamed: 5  Unnamed: 9 Unnamed: 10 Unnamed: 11
# 275  Journal log list         NaN       Date:  04/06/2024
# 276  Journal log list         NaN       Date:  04/06/2024
# 277  Journal log list         NaN       Date:  04/06/2024
# 278  Journal log list         NaN       Date:  04/06/2024
# 279  Journal log list         NaN       Date:  04/06/2024
# 280  Journal log list         NaN       Date:  04/06/2024
# 281  Journal log list         NaN       Date:  04/06/2024
# 282  Journal log list         NaN       Date:  04/06/2024
# 283  Journal log list         NaN       Date:  04/06/2024
# 284  Journal log list         NaN       Date:  04/06/2024
# 285  Journal log list         NaN       Date:  04/06/2024
# 286  Journal log list         NaN       Date:  04/06/2024
# 287  Journal log list         NaN       Date:  04/06/2024
# 288  Journal log list         NaN       Date:  04/06/2024
# 289  Journal log list         NaN       Date:  04/06/2024
# 290  Journal log list         NaN       Date:  04/06/2024
# 291  Journal log list         NaN       Date:  04/06/2024
# 292  Journal log list         NaN       Date:  04/06/2024
# 293  Journal log list         NaN       Date:  04/06/2024
# 294  Journal log list         NaN       Date:  04/06/2024
# 295  Journal log list         NaN       Date:  04/06/2024
# 296  Journal log list         NaN       Date:  04/06/2024
# 297  Journal log list         NaN       Date:  04/06/2024
# 298  Journal log list         NaN       Date:  04/06/2024
# 299  Journal log list         NaN       Date:  04/06/2024

# %%
df_rua.fillna('', inplace=True)
df_rua
# Out:
#       CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n Unnamed: 1  \
# 0                                  1 of 10346
# 1                                  1 of 10346
# 2                                  1 of 10346
# 3                                  1 of 10346
# 4                                  1 of 10346
# ...                                       ...        ...
# 99858                              1 of 10346
# 99859                              1 of 10346
# 99860                              1 of 10346
# 99861                              1 of 10346
# 99862                              1 of 10346
#
#                                      Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0
# 1
# 2                                    NEW ANTRIM
# 3                         "F","FILE993","Z","D"
# 4                                    NEW ANTRIM
# ...                                         ...        ...        ...
# 99858                                NEW ANTRIM
# 99859  REG           31-12-2023 05:24    000003
# 99860                                    Inline
# 99861                                   Receive
# 99862
#
#              Unnamed: 5 Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0      Journal log list                  Date:  04/06/2024
# 1      Journal log list                  Date:  04/06/2024
# 2      Journal log list                  Date:  04/06/2024
# 3      Journal log list                  Date:  04/06/2024
# 4      Journal log list                  Date:  04/06/2024
# ...                 ...        ...         ...         ...
# 99858  Journal log list                  Date:  04/06/2024
# 99859  Journal log list                  Date:  04/06/2024
# 99860  Journal log list                  Date:  04/06/2024
# 99861  Journal log list                  Date:  04/06/2024
# 99862  Journal log list                  Date:  04/06/2024
#
# [99863 rows x 9 columns]

# %%
df_rua.iloc[275:300]
# Out:
#     CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n Unnamed: 1  \
# 275                              1 of 10346
# 276                              1 of 10346
# 277                              1 of 10346
# 278                              1 of 10346
# 279                              1 of 10346
# 280                              1 of 10346
# 281                              1 of 10346
# 282                              1 of 10346
# 283                              1 of 10346
# 284                              1 of 10346
# 285                              1 of 10346
# 286                              1 of 10346
# 287                              1 of 10346
# 288                              1 of 10346
# 289                              1 of 10346
# 290                              1 of 10346
# 291                              1 of 10346
# 292                              1 of 10346
# 293                              1 of 10346
# 294                              1 of 10346
# 295                              1 of 10346
# 296                              1 of 10346
# 297                              1 of 10346
# 298                              1 of 10346
# 299                              1 of 10346
#
#                                    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 275         1  PTN TOAST                €1.75
# 276         1  HOT CHOC                 €3.70
# 277            SUBTOTAL                €36.30
# 278         1  APPLE JUICE SM           €2.95
# 279         1  LATTE                    €3.80
# 280                                      9 No
# 281            EX VAT @ 13.5%          €10.67
# 282
# 283
# 284                                NEW ANTRIM
# 285  REG  SINEAD   03-01-2023 15:05    000278
# 286                                NEW ANTRIM
# 287  REG  SINEAD   03-01-2023 15:05    000279
# 288            SHOW  TABLES                 2
# 289         1  CHK TSD                 €11.50
# 290                                   SAUTEED
# 291
# 292
# 293
# 294            _C_H_A_N_G_E             €5.50
# 295                                NEW ANTRIM
# 296  REG  SINEAD   03-01-2023 15:14    000289
# 297                                NEW ANTRIM
# 298  REG  SINEAD   03-01-2023 15:14    000290
# 299            SHOW  TABLES                 1
#
#            Unnamed: 5 Unnamed: 9 Unnamed: 10 Unnamed: 11
# 275  Journal log list                  Date:  04/06/2024
# 276  Journal log list                  Date:  04/06/2024
# 277  Journal log list                  Date:  04/06/2024
# 278  Journal log list                  Date:  04/06/2024
# 279  Journal log list                  Date:  04/06/2024
# 280  Journal log list                  Date:  04/06/2024
# 281  Journal log list                  Date:  04/06/2024
# 282  Journal log list                  Date:  04/06/2024
# 283  Journal log list                  Date:  04/06/2024
# 284  Journal log list                  Date:  04/06/2024
# 285  Journal log list                  Date:  04/06/2024
# 286  Journal log list                  Date:  04/06/2024
# 287  Journal log list                  Date:  04/06/2024
# 288  Journal log list                  Date:  04/06/2024
# 289  Journal log list                  Date:  04/06/2024
# 290  Journal log list                  Date:  04/06/2024
# 291  Journal log list                  Date:  04/06/2024
# 292  Journal log list                  Date:  04/06/2024
# 293  Journal log list                  Date:  04/06/2024
# 294  Journal log list                  Date:  04/06/2024
# 295  Journal log list                  Date:  04/06/2024
# 296  Journal log list                  Date:  04/06/2024
# 297  Journal log list                  Date:  04/06/2024
# 298  Journal log list                  Date:  04/06/2024
# 299  Journal log list                  Date:  04/06/2024

# %%
df_rua[['Type', 'Name', 'Date', 'Time', 'Number']] = df_rua['Unnamed: 2'].str.split(' ', 4, expand=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-88608455c6cb> in <cell line: 1>()
# ----> 1 df_rua[['Type', 'Name', 'Date', 'Time', 'Number']] = df_rua['Unnamed: 2'].str.split(' ', 4, expand=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     127                 )
#     128                 raise TypeError(msg)
# --> 129             return func(self, *args, **kwargs)
#     130
#     131         wrapper.__name__ = func_name
#
# TypeError: StringMethods.split() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
df_rua.columns
# Out:
# Index(['CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='object')

# %%
# Fonction pour diviser et créer de nouvelles colonnes
def split_information(row):
    parts = row.split(' ')
    prenom = ' '.join(parts[:2])
    date = parts[2]
    heure = parts[3]
    transaction_num = parts[4]
    return pd.Series([prenom, date, heure, transaction_num])

# Appliquer la fonction et créer de nouvelles colonnes
df_rua[['Prenom', 'Date', 'Heure', 'Transaction']] = df_rua['Unnamed: 2'].apply(split_information)

# Afficher le DataFrame résultant
print(df_rua)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-acebb2f5f041> in <cell line: 11>()
#       9
#      10 # Appliquer la fonction et créer de nouvelles colonnes
# ---> 11 df_rua[['Prenom', 'Date', 'Heure', 'Transaction']] = df_rua['Unnamed: 2'].apply(split_information)
#      12
#      13 # Afficher le DataFrame résultant
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4628         dtype: float64
#    4629         """
# -> 4630         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4631
#    4632     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1023
#    1024         # self.f is Callable
# -> 1025         return self.apply_standard()
#    1026
#    1027     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1074             else:
#    1075                 values = obj.astype(object)._values
# -> 1076                 mapped = lib.map_infer(
#    1077                     values,
#    1078                     f,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-29-acebb2f5f041> in split_information(row)
#       3     parts = row.split(' ')
#       4     prenom = ' '.join(parts[:2])
# ----> 5     date = parts[2]
#       6     heure = parts[3]
#       7     transaction_num = parts[4]
#
# IndexError: list index out of range

# %%
def split_information(row):
    parts = row.split(' ')
    if len(parts) >= 5:  # Vérifier s'il y a suffisamment d'éléments dans la liste
        prenom = ' '.join(parts[:2])
        date = parts[2]
        heure = parts[3]
        transaction_num = parts[4]
        return pd.Series([prenom, date, heure, transaction_num])
    else:
        return pd.Series(['', '', '', ''])  # Retourner des valeurs vides si la ligne est incorrecte

# %%
df_rua
# Out:
#       CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n Unnamed: 1  \
# 0                                  1 of 10346
# 1                                  1 of 10346
# 2                                  1 of 10346
# 3                                  1 of 10346
# 4                                  1 of 10346
# ...                                       ...        ...
# 99858                              1 of 10346
# 99859                              1 of 10346
# 99860                              1 of 10346
# 99861                              1 of 10346
# 99862                              1 of 10346
#
#                                      Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0
# 1
# 2                                    NEW ANTRIM
# 3                         "F","FILE993","Z","D"
# 4                                    NEW ANTRIM
# ...                                         ...        ...        ...
# 99858                                NEW ANTRIM
# 99859  REG           31-12-2023 05:24    000003
# 99860                                    Inline
# 99861                                   Receive
# 99862
#
#              Unnamed: 5 Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0      Journal log list                  Date:  04/06/2024
# 1      Journal log list                  Date:  04/06/2024
# 2      Journal log list                  Date:  04/06/2024
# 3      Journal log list                  Date:  04/06/2024
# 4      Journal log list                  Date:  04/06/2024
# ...                 ...        ...         ...         ...
# 99858  Journal log list                  Date:  04/06/2024
# 99859  Journal log list                  Date:  04/06/2024
# 99860  Journal log list                  Date:  04/06/2024
# 99861  Journal log list                  Date:  04/06/2024
# 99862  Journal log list                  Date:  04/06/2024
#
# [99863 rows x 9 columns]

# %%
df_rua.iloc[275:300]
# Out:
#     CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n Unnamed: 1  \
# 275                              1 of 10346
# 276                              1 of 10346
# 277                              1 of 10346
# 278                              1 of 10346
# 279                              1 of 10346
# 280                              1 of 10346
# 281                              1 of 10346
# 282                              1 of 10346
# 283                              1 of 10346
# 284                              1 of 10346
# 285                              1 of 10346
# 286                              1 of 10346
# 287                              1 of 10346
# 288                              1 of 10346
# 289                              1 of 10346
# 290                              1 of 10346
# 291                              1 of 10346
# 292                              1 of 10346
# 293                              1 of 10346
# 294                              1 of 10346
# 295                              1 of 10346
# 296                              1 of 10346
# 297                              1 of 10346
# 298                              1 of 10346
# 299                              1 of 10346
#
#                                    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 275         1  PTN TOAST                €1.75
# 276         1  HOT CHOC                 €3.70
# 277            SUBTOTAL                €36.30
# 278         1  APPLE JUICE SM           €2.95
# 279         1  LATTE                    €3.80
# 280                                      9 No
# 281            EX VAT @ 13.5%          €10.67
# 282
# 283
# 284                                NEW ANTRIM
# 285  REG  SINEAD   03-01-2023 15:05    000278
# 286                                NEW ANTRIM
# 287  REG  SINEAD   03-01-2023 15:05    000279
# 288            SHOW  TABLES                 2
# 289         1  CHK TSD                 €11.50
# 290                                   SAUTEED
# 291
# 292
# 293
# 294            _C_H_A_N_G_E             €5.50
# 295                                NEW ANTRIM
# 296  REG  SINEAD   03-01-2023 15:14    000289
# 297                                NEW ANTRIM
# 298  REG  SINEAD   03-01-2023 15:14    000290
# 299            SHOW  TABLES                 1
#
#            Unnamed: 5 Unnamed: 9 Unnamed: 10 Unnamed: 11
# 275  Journal log list                  Date:  04/06/2024
# 276  Journal log list                  Date:  04/06/2024
# 277  Journal log list                  Date:  04/06/2024
# 278  Journal log list                  Date:  04/06/2024
# 279  Journal log list                  Date:  04/06/2024
# 280  Journal log list                  Date:  04/06/2024
# 281  Journal log list                  Date:  04/06/2024
# 282  Journal log list                  Date:  04/06/2024
# 283  Journal log list                  Date:  04/06/2024
# 284  Journal log list                  Date:  04/06/2024
# 285  Journal log list                  Date:  04/06/2024
# 286  Journal log list                  Date:  04/06/2024
# 287  Journal log list                  Date:  04/06/2024
# 288  Journal log list                  Date:  04/06/2024
# 289  Journal log list                  Date:  04/06/2024
# 290  Journal log list                  Date:  04/06/2024
# 291  Journal log list                  Date:  04/06/2024
# 292  Journal log list                  Date:  04/06/2024
# 293  Journal log list                  Date:  04/06/2024
# 294  Journal log list                  Date:  04/06/2024
# 295  Journal log list                  Date:  04/06/2024
# 296  Journal log list                  Date:  04/06/2024
# 297  Journal log list                  Date:  04/06/2024
# 298  Journal log list                  Date:  04/06/2024
# 299  Journal log list                  Date:  04/06/2024

# %%
import pandas as pd
import re  # Ajouter cette ligne pour importer le module d'expressions régulières

# Fonction pour extraire les informations
def extract_information(row):
    match = re.match(r'([A-Z\s]+) (\d{2}-\d{2}-\d{4}|\d{4}-\d{2}-\d{2}) (\d{2}:\d{2}) (\d+)', row)
    if match:
        prenom = match.group(1).strip()
        date = match.group(2)
        heure = match.group(3)
        transaction_num = match.group(4)
        return pd.Series([prenom, date, heure, transaction_num])
    else:
        return pd.Series(['', '', '', ''])  # Retourner des valeurs vides si le format ne correspond pas

# Appliquer la fonction et créer de nouvelles colonnes
df_rua[['Prenom', 'Date', 'Heure', 'Transaction']] = df_rua['Unnamed: 2'].apply(extract_information)

# Afficher le DataFrame résultant
(df_rua)
# Out:
#       CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n Unnamed: 1  \
# 0                                  1 of 10346
# 1                                  1 of 10346
# 2                                  1 of 10346
# 3                                  1 of 10346
# 4                                  1 of 10346
# ...                                       ...        ...
# 99858                              1 of 10346
# 99859                              1 of 10346
# 99860                              1 of 10346
# 99861                              1 of 10346
# 99862                              1 of 10346
#
#                                      Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0
# 1
# 2                                    NEW ANTRIM
# 3                         "F","FILE993","Z","D"
# 4                                    NEW ANTRIM
# ...                                         ...        ...        ...
# 99858                                NEW ANTRIM
# 99859  REG           31-12-2023 05:24    000003
# 99860                                    Inline
# 99861                                   Receive
# 99862
#
#              Unnamed: 5 Unnamed: 9 Unnamed: 10 Unnamed: 11 Prenom Date Heure  \
# 0      Journal log list                  Date:  04/06/2024
# 1      Journal log list                  Date:  04/06/2024
# 2      Journal log list                  Date:  04/06/2024
# 3      Journal log list                  Date:  04/06/2024
# 4      Journal log list                  Date:  04/06/2024
# ...                 ...        ...         ...         ...    ...  ...   ...
# 99858  Journal log list                  Date:  04/06/2024
# 99859  Journal log list                  Date:  04/06/2024
# 99860  Journal log list                  Date:  04/06/2024
# 99861  Journal log list                  Date:  04/06/2024
# 99862  Journal log list                  Date:  04/06/2024
#
#       Transaction
# 0
# 1
# 2
# 3
# 4
# ...           ...
# 99858
# 99859
# 99860
# 99861
# 99862
#
# [99863 rows x 13 columns]

# %%
df_rua.iloc[275:300]
# Out:
#     CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n Unnamed: 1  \
# 275                              1 of 10346
# 276                              1 of 10346
# 277                              1 of 10346
# 278                              1 of 10346
# 279                              1 of 10346
# 280                              1 of 10346
# 281                              1 of 10346
# 282                              1 of 10346
# 283                              1 of 10346
# 284                              1 of 10346
# 285                              1 of 10346
# 286                              1 of 10346
# 287                              1 of 10346
# 288                              1 of 10346
# 289                              1 of 10346
# 290                              1 of 10346
# 291                              1 of 10346
# 292                              1 of 10346
# 293                              1 of 10346
# 294                              1 of 10346
# 295                              1 of 10346
# 296                              1 of 10346
# 297                              1 of 10346
# 298                              1 of 10346
# 299                              1 of 10346
#
#                                    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 275         1  PTN TOAST                €1.75
# 276         1  HOT CHOC                 €3.70
# 277            SUBTOTAL                €36.30
# 278         1  APPLE JUICE SM           €2.95
# 279         1  LATTE                    €3.80
# 280                                      9 No
# 281            EX VAT @ 13.5%          €10.67
# 282
# 283
# 284                                NEW ANTRIM
# 285  REG  SINEAD   03-01-2023 15:05    000278
# 286                                NEW ANTRIM
# 287  REG  SINEAD   03-01-2023 15:05    000279
# 288            SHOW  TABLES                 2
# 289         1  CHK TSD                 €11.50
# 290                                   SAUTEED
# 291
# 292
# 293
# 294            _C_H_A_N_G_E             €5.50
# 295                                NEW ANTRIM
# 296  REG  SINEAD   03-01-2023 15:14    000289
# 297                                NEW ANTRIM
# 298  REG  SINEAD   03-01-2023 15:14    000290
# 299            SHOW  TABLES                 1
#
#            Unnamed: 5 Unnamed: 9 Unnamed: 10 Unnamed: 11 Prenom Date Heure  \
# 275  Journal log list                  Date:  04/06/2024
# 276  Journal log list                  Date:  04/06/2024
# 277  Journal log list                  Date:  04/06/2024
# 278  Journal log list                  Date:  04/06/2024
# 279  Journal log list                  Date:  04/06/2024
# 280  Journal log list                  Date:  04/06/2024
# 281  Journal log list                  Date:  04/06/2024
# 282  Journal log list                  Date:  04/06/2024
# 283  Journal log list                  Date:  04/06/2024
# 284  Journal log list                  Date:  04/06/2024
# 285  Journal log list                  Date:  04/06/2024
# 286  Journal log list                  Date:  04/06/2024
# 287  Journal log list                  Date:  04/06/2024
# 288  Journal log list                  Date:  04/06/2024
# 289  Journal log list                  Date:  04/06/2024
# 290  Journal log list                  Date:  04/06/2024
# 291  Journal log list                  Date:  04/06/2024
# 292  Journal log list                  Date:  04/06/2024
# 293  Journal log list                  Date:  04/06/2024
# 294  Journal log list                  Date:  04/06/2024
# 295  Journal log list                  Date:  04/06/2024
# 296  Journal log list                  Date:  04/06/2024
# 297  Journal log list                  Date:  04/06/2024
# 298  Journal log list                  Date:  04/06/2024
# 299  Journal log list                  Date:  04/06/2024
#
#     Transaction
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299

# %%
# Fonction pour extraire les informations
def extract_information(row):
    match = re.match(r'([A-Z\s]+)\s+(\d{2}-\d{2}-\d{4}|\d{4}-\d{2}-\d{2})\s+(\d{2}:\d{2})\s+(\d+)', row)
    if match:
        prenom = match.group(1).strip()
        date = match.group(2)
        heure = match.group(3)
        transaction_num = match.group(4)
        return pd.Series([prenom, date, heure, transaction_num])
    else:
        return pd.Series(['', '', '', ''])  # Retourner des valeurs vides si le format ne correspond pas

# Appliquer la fonction et créer de nouvelles colonnes
df_rua[['Prenom', 'Date', 'Heure', 'Transaction']] = df_rua['Unnamed: 2'].apply(extract_information)

# %%
df_rua.iloc[275:300]
# Out:
#     CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n Unnamed: 1  \
# 275                              1 of 10346
# 276                              1 of 10346
# 277                              1 of 10346
# 278                              1 of 10346
# 279                              1 of 10346
# 280                              1 of 10346
# 281                              1 of 10346
# 282                              1 of 10346
# 283                              1 of 10346
# 284                              1 of 10346
# 285                              1 of 10346
# 286                              1 of 10346
# 287                              1 of 10346
# 288                              1 of 10346
# 289                              1 of 10346
# 290                              1 of 10346
# 291                              1 of 10346
# 292                              1 of 10346
# 293                              1 of 10346
# 294                              1 of 10346
# 295                              1 of 10346
# 296                              1 of 10346
# 297                              1 of 10346
# 298                              1 of 10346
# 299                              1 of 10346
#
#                                    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 275         1  PTN TOAST                €1.75
# 276         1  HOT CHOC                 €3.70
# 277            SUBTOTAL                €36.30
# 278         1  APPLE JUICE SM           €2.95
# 279         1  LATTE                    €3.80
# 280                                      9 No
# 281            EX VAT @ 13.5%          €10.67
# 282
# 283
# 284                                NEW ANTRIM
# 285  REG  SINEAD   03-01-2023 15:05    000278
# 286                                NEW ANTRIM
# 287  REG  SINEAD   03-01-2023 15:05    000279
# 288            SHOW  TABLES                 2
# 289         1  CHK TSD                 €11.50
# 290                                   SAUTEED
# 291
# 292
# 293
# 294            _C_H_A_N_G_E             €5.50
# 295                                NEW ANTRIM
# 296  REG  SINEAD   03-01-2023 15:14    000289
# 297                                NEW ANTRIM
# 298  REG  SINEAD   03-01-2023 15:14    000290
# 299            SHOW  TABLES                 1
#
#            Unnamed: 5 Unnamed: 9 Unnamed: 10 Unnamed: 11       Prenom  \
# 275  Journal log list                  Date:  04/06/2024
# 276  Journal log list                  Date:  04/06/2024
# 277  Journal log list                  Date:  04/06/2024
# 278  Journal log list                  Date:  04/06/2024
# 279  Journal log list                  Date:  04/06/2024
# 280  Journal log list                  Date:  04/06/2024
# 281  Journal log list                  Date:  04/06/2024
# 282  Journal log list                  Date:  04/06/2024
# 283  Journal log list                  Date:  04/06/2024
# 284  Journal log list                  Date:  04/06/2024
# 285  Journal log list                  Date:  04/06/2024  REG  SINEAD
# 286  Journal log list                  Date:  04/06/2024
# 287  Journal log list                  Date:  04/06/2024  REG  SINEAD
# 288  Journal log list                  Date:  04/06/2024
# 289  Journal log list                  Date:  04/06/2024
# 290  Journal log list                  Date:  04/06/2024
# 291  Journal log list                  Date:  04/06/2024
# 292  Journal log list                  Date:  04/06/2024
# 293  Journal log list                  Date:  04/06/2024
# 294  Journal log list                  Date:  04/06/2024
# 295  Journal log list                  Date:  04/06/2024
# 296  Journal log list                  Date:  04/06/2024  REG  SINEAD
# 297  Journal log list                  Date:  04/06/2024
# 298  Journal log list                  Date:  04/06/2024  REG  SINEAD
# 299  Journal log list                  Date:  04/06/2024
#
#            Date  Heure Transaction
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285  03-01-2023  15:05      000278
# 286
# 287  03-01-2023  15:05      000279
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296  03-01-2023  15:14      000289
# 297
# 298  03-01-2023  15:14      000290
# 299

# %%
# Fonction pour extraire le prix
def extract_price(row):
    match = re.search(r'€(\d+\.\d{2})', row)
    if match:
        return match.group(1)
    else:
        return ''

# Appliquer la fonction et créer une nouvelle colonne 'Prix'
df_rua['Prix'] = df_rua['Unnamed: 2'].apply(extract_price)

# %%
df_rua.iloc[275:300]
# Out:
#     CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n Unnamed: 1  \
# 275                              1 of 10346
# 276                              1 of 10346
# 277                              1 of 10346
# 278                              1 of 10346
# 279                              1 of 10346
# 280                              1 of 10346
# 281                              1 of 10346
# 282                              1 of 10346
# 283                              1 of 10346
# 284                              1 of 10346
# 285                              1 of 10346
# 286                              1 of 10346
# 287                              1 of 10346
# 288                              1 of 10346
# 289                              1 of 10346
# 290                              1 of 10346
# 291                              1 of 10346
# 292                              1 of 10346
# 293                              1 of 10346
# 294                              1 of 10346
# 295                              1 of 10346
# 296                              1 of 10346
# 297                              1 of 10346
# 298                              1 of 10346
# 299                              1 of 10346
#
#                                    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 275         1  PTN TOAST                €1.75
# 276         1  HOT CHOC                 €3.70
# 277            SUBTOTAL                €36.30
# 278         1  APPLE JUICE SM           €2.95
# 279         1  LATTE                    €3.80
# 280                                      9 No
# 281            EX VAT @ 13.5%          €10.67
# 282
# 283
# 284                                NEW ANTRIM
# 285  REG  SINEAD   03-01-2023 15:05    000278
# 286                                NEW ANTRIM
# 287  REG  SINEAD   03-01-2023 15:05    000279
# 288            SHOW  TABLES                 2
# 289         1  CHK TSD                 €11.50
# 290                                   SAUTEED
# 291
# 292
# 293
# 294            _C_H_A_N_G_E             €5.50
# 295                                NEW ANTRIM
# 296  REG  SINEAD   03-01-2023 15:14    000289
# 297                                NEW ANTRIM
# 298  REG  SINEAD   03-01-2023 15:14    000290
# 299            SHOW  TABLES                 1
#
#            Unnamed: 5 Unnamed: 9 Unnamed: 10 Unnamed: 11       Prenom  \
# 275  Journal log list                  Date:  04/06/2024
# 276  Journal log list                  Date:  04/06/2024
# 277  Journal log list                  Date:  04/06/2024
# 278  Journal log list                  Date:  04/06/2024
# 279  Journal log list                  Date:  04/06/2024
# 280  Journal log list                  Date:  04/06/2024
# 281  Journal log list                  Date:  04/06/2024
# 282  Journal log list                  Date:  04/06/2024
# 283  Journal log list                  Date:  04/06/2024
# 284  Journal log list                  Date:  04/06/2024
# 285  Journal log list                  Date:  04/06/2024  REG  SINEAD
# 286  Journal log list                  Date:  04/06/2024
# 287  Journal log list                  Date:  04/06/2024  REG  SINEAD
# 288  Journal log list                  Date:  04/06/2024
# 289  Journal log list                  Date:  04/06/2024
# 290  Journal log list                  Date:  04/06/2024
# 291  Journal log list                  Date:  04/06/2024
# 292  Journal log list                  Date:  04/06/2024
# 293  Journal log list                  Date:  04/06/2024
# 294  Journal log list                  Date:  04/06/2024
# 295  Journal log list                  Date:  04/06/2024
# 296  Journal log list                  Date:  04/06/2024  REG  SINEAD
# 297  Journal log list                  Date:  04/06/2024
# 298  Journal log list                  Date:  04/06/2024  REG  SINEAD
# 299  Journal log list                  Date:  04/06/2024
#
#            Date  Heure Transaction   Prix
# 275                                  1.75
# 276                                  3.70
# 277                                 36.30
# 278                                  2.95
# 279                                  3.80
# 280
# 281                                 10.67
# 282
# 283
# 284
# 285  03-01-2023  15:05      000278
# 286
# 287  03-01-2023  15:05      000279
# 288
# 289                                 11.50
# 290
# 291
# 292
# 293
# 294                                  5.50
# 295
# 296  03-01-2023  15:14      000289
# 297
# 298  03-01-2023  15:14      000290
# 299

# %%
df_rua.columns
# Out:
# Index(['CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Prenom', 'Date', 'Heure', 'Transaction', 'Prix'],
#       dtype='object')

# %%
# Liste des colonnes à supprimer
cols_to_drop = ['Unnamed: 1', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11']

# Supprimer les colonnes spécifiées
df_rua.drop(cols_to_drop, axis=1, inplace=True)

# %%
df_rua.iloc[350:375]
# Out:
#     CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n  \
# 350                              1 of 10346
# 351                              1 of 10346
# 352                              1 of 10346
# 353                              1 of 10346
# 354                              1 of 10346
# 355                              1 of 10346
# 356                              1 of 10346
# 357                              1 of 10346
# 358                              1 of 10346
# 359                              1 of 10346
# 360                              1 of 10346
# 361                              1 of 10346
# 362                              1 of 10346
# 363                              1 of 10346
# 364                              1 of 10346
# 365                              1 of 10346
# 366                              1 of 10346
# 367                              1 of 10346
# 368                              1 of 10346
# 369                              1 of 10346
# 370                              1 of 10346
# 371                              1 of 10346
# 372                              1 of 10346
# 373                              1 of 10346
# 374                              1 of 10346
#
#                                    Unnamed: 2 Unnamed: 4       Prenom  \
# 350  REG  SINEAD   03-01-2023 16:35    000377             REG  SINEAD
# 351            SHOW  TABLES                 6
# 352            SUBTOTAL                 €0.00
# 353         1  GOATS TSD               €11.50
# 354                                     PASTA
# 355                                     1  DU
# 356
# 357
# 358                                     PASTA
# 359                                      2 No
# 360            HOLD BALANCE  _ _ _€_2_5_._4_5
# 361                                NEW ANTRIM
# 362  REG  SINEAD   03-01-2023 16:46    000389             REG  SINEAD
# 363            SHOW  TABLES                 9
# 364            SUBTOTAL                €15.95
# 365                            1  AMERICANO L
# 366
# 367
# 368         1  PATE SALAD              €10.95
# 369         1  SOUP                     €5.50
# 370                                      4 No
# 371            EX VAT@9%               €22.07
# 372            VAT@9%                   €1.98
# 373            _T_O_T_A_L    _ _ _€_2_4_._0_5
# 374            Visa                    €24.05
#
#            Date  Heure Transaction   Prix
# 350  03-01-2023  16:35      000377
# 351
# 352                                  0.00
# 353                                 11.50
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362  03-01-2023  16:46      000389
# 363
# 364                                 15.95
# 365
# 366
# 367
# 368                                 10.95
# 369                                  5.50
# 370
# 371                                 22.07
# 372                                  1.98
# 373
# 374                                 24.05

# %%
# Fonction pour extraire le total de la transaction
def extract_total_transaction(data):
    total_transaction = ''
    for cell in data.split('\n'):
        match = re.search(r'_T_O_T_A_L\s*€(\d+\.\d{2})', cell)
        if match:
            total_transaction = match.group(1)
    return total_transaction

# Appliquer la fonction et créer une nouvelle colonne 'Total Transaction'
df_rua['Total Transaction'] = df_rua['Unnamed: 2'].apply(extract_total_transaction)

# %%
df_rua.iloc[350:375]
# Out:
#     CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n  \
# 350                              1 of 10346
# 351                              1 of 10346
# 352                              1 of 10346
# 353                              1 of 10346
# 354                              1 of 10346
# 355                              1 of 10346
# 356                              1 of 10346
# 357                              1 of 10346
# 358                              1 of 10346
# 359                              1 of 10346
# 360                              1 of 10346
# 361                              1 of 10346
# 362                              1 of 10346
# 363                              1 of 10346
# 364                              1 of 10346
# 365                              1 of 10346
# 366                              1 of 10346
# 367                              1 of 10346
# 368                              1 of 10346
# 369                              1 of 10346
# 370                              1 of 10346
# 371                              1 of 10346
# 372                              1 of 10346
# 373                              1 of 10346
# 374                              1 of 10346
#
#                                    Unnamed: 2 Unnamed: 4       Prenom  \
# 350  REG  SINEAD   03-01-2023 16:35    000377             REG  SINEAD
# 351            SHOW  TABLES                 6
# 352            SUBTOTAL                 €0.00
# 353         1  GOATS TSD               €11.50
# 354                                     PASTA
# 355                                     1  DU
# 356
# 357
# 358                                     PASTA
# 359                                      2 No
# 360            HOLD BALANCE  _ _ _€_2_5_._4_5
# 361                                NEW ANTRIM
# 362  REG  SINEAD   03-01-2023 16:46    000389             REG  SINEAD
# 363            SHOW  TABLES                 9
# 364            SUBTOTAL                €15.95
# 365                            1  AMERICANO L
# 366
# 367
# 368         1  PATE SALAD              €10.95
# 369         1  SOUP                     €5.50
# 370                                      4 No
# 371            EX VAT@9%               €22.07
# 372            VAT@9%                   €1.98
# 373            _T_O_T_A_L    _ _ _€_2_4_._0_5
# 374            Visa                    €24.05
#
#            Date  Heure Transaction   Prix Total Transaction
# 350  03-01-2023  16:35      000377
# 351
# 352                                  0.00
# 353                                 11.50
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362  03-01-2023  16:46      000389
# 363
# 364                                 15.95
# 365
# 366
# 367
# 368                                 10.95
# 369                                  5.50
# 370
# 371                                 22.07
# 372                                  1.98
# 373
# 374                                 24.05

# %%
# Fonction pour extraire le total de la transaction
def extract_total_transaction(row):
    # Expression régulière pour trouver le total de la transaction avec underscores
    match = re.search(r'_T_O_T_A_L\s*_\s*_\s*_€_([0-9_]+(?:\.\d{2}))', row)
    if match:
        # Nettoyer le montant pour retirer les underscores
        total_str = match.group(1).replace('_', '')
        return total_str
    else:
        return ''

# Appliquer la fonction à chaque cellule de la colonne 'Unnamed: 2' et créer une nouvelle colonne 'Total Transaction'
df_rua['Total Transaction'] = df_rua['Unnamed: 2'].apply(extract_total_transaction)

# %%
df_rua.iloc[350:375]
# Out:
#     CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n  \
# 350                              1 of 10346
# 351                              1 of 10346
# 352                              1 of 10346
# 353                              1 of 10346
# 354                              1 of 10346
# 355                              1 of 10346
# 356                              1 of 10346
# 357                              1 of 10346
# 358                              1 of 10346
# 359                              1 of 10346
# 360                              1 of 10346
# 361                              1 of 10346
# 362                              1 of 10346
# 363                              1 of 10346
# 364                              1 of 10346
# 365                              1 of 10346
# 366                              1 of 10346
# 367                              1 of 10346
# 368                              1 of 10346
# 369                              1 of 10346
# 370                              1 of 10346
# 371                              1 of 10346
# 372                              1 of 10346
# 373                              1 of 10346
# 374                              1 of 10346
#
#                                    Unnamed: 2 Unnamed: 4       Prenom  \
# 350  REG  SINEAD   03-01-2023 16:35    000377             REG  SINEAD
# 351            SHOW  TABLES                 6
# 352            SUBTOTAL                 €0.00
# 353         1  GOATS TSD               €11.50
# 354                                     PASTA
# 355                                     1  DU
# 356
# 357
# 358                                     PASTA
# 359                                      2 No
# 360            HOLD BALANCE  _ _ _€_2_5_._4_5
# 361                                NEW ANTRIM
# 362  REG  SINEAD   03-01-2023 16:46    000389             REG  SINEAD
# 363            SHOW  TABLES                 9
# 364            SUBTOTAL                €15.95
# 365                            1  AMERICANO L
# 366
# 367
# 368         1  PATE SALAD              €10.95
# 369         1  SOUP                     €5.50
# 370                                      4 No
# 371            EX VAT@9%               €22.07
# 372            VAT@9%                   €1.98
# 373            _T_O_T_A_L    _ _ _€_2_4_._0_5
# 374            Visa                    €24.05
#
#            Date  Heure Transaction   Prix Total Transaction
# 350  03-01-2023  16:35      000377
# 351
# 352                                  0.00
# 353                                 11.50
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362  03-01-2023  16:46      000389
# 363
# 364                                 15.95
# 365
# 366
# 367
# 368                                 10.95
# 369                                  5.50
# 370
# 371                                 22.07
# 372                                  1.98
# 373
# 374                                 24.05

# %%
# Fonction pour extraire le total de la transaction
def extract_total_transaction(row):
    match = re.search(r'_T_O_T_A_L\s*_[\s\d_]*€(\d+\.\d{2})', row)
    if match:
        return match.group(1)
    else:
        return ''

# Appliquer la fonction et créer une nouvelle colonne 'Total Transaction'
df_rua['Total Transaction'] = df_rua['Unnamed: 2'].apply(extract_total_transaction)

# %%
df_rua.iloc[350:375]
# Out:
#     CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n  \
# 350                              1 of 10346
# 351                              1 of 10346
# 352                              1 of 10346
# 353                              1 of 10346
# 354                              1 of 10346
# 355                              1 of 10346
# 356                              1 of 10346
# 357                              1 of 10346
# 358                              1 of 10346
# 359                              1 of 10346
# 360                              1 of 10346
# 361                              1 of 10346
# 362                              1 of 10346
# 363                              1 of 10346
# 364                              1 of 10346
# 365                              1 of 10346
# 366                              1 of 10346
# 367                              1 of 10346
# 368                              1 of 10346
# 369                              1 of 10346
# 370                              1 of 10346
# 371                              1 of 10346
# 372                              1 of 10346
# 373                              1 of 10346
# 374                              1 of 10346
#
#                                    Unnamed: 2 Unnamed: 4       Prenom  \
# 350  REG  SINEAD   03-01-2023 16:35    000377             REG  SINEAD
# 351            SHOW  TABLES                 6
# 352            SUBTOTAL                 €0.00
# 353         1  GOATS TSD               €11.50
# 354                                     PASTA
# 355                                     1  DU
# 356
# 357
# 358                                     PASTA
# 359                                      2 No
# 360            HOLD BALANCE  _ _ _€_2_5_._4_5
# 361                                NEW ANTRIM
# 362  REG  SINEAD   03-01-2023 16:46    000389             REG  SINEAD
# 363            SHOW  TABLES                 9
# 364            SUBTOTAL                €15.95
# 365                            1  AMERICANO L
# 366
# 367
# 368         1  PATE SALAD              €10.95
# 369         1  SOUP                     €5.50
# 370                                      4 No
# 371            EX VAT@9%               €22.07
# 372            VAT@9%                   €1.98
# 373            _T_O_T_A_L    _ _ _€_2_4_._0_5
# 374            Visa                    €24.05
#
#            Date  Heure Transaction   Prix Total Transaction
# 350  03-01-2023  16:35      000377
# 351
# 352                                  0.00
# 353                                 11.50
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362  03-01-2023  16:46      000389
# 363
# 364                                 15.95
# 365
# 366
# 367
# 368                                 10.95
# 369                                  5.50
# 370
# 371                                 22.07
# 372                                  1.98
# 373
# 374                                 24.05

# %%
# Fonction pour extraire le total de la transaction
def extract_total_transaction(row):
    match = re.search(r'_T_O_T_A_L\s*_[\s\d_]*€([\d._]+)', row)
    if match:
        total_str = match.group(1).replace('_', '').replace('.', '').replace(',', '.')
        return total_str
    else:
        return ''

# Appliquer la fonction et créer une nouvelle colonne 'Total Transaction'
df_rua['Total Transaction'] = df_rua['Unnamed: 2'].apply(extract_total_transaction)

# %%
df_rua.iloc[350:375]
# Out:
#     CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n  \
# 350                              1 of 10346
# 351                              1 of 10346
# 352                              1 of 10346
# 353                              1 of 10346
# 354                              1 of 10346
# 355                              1 of 10346
# 356                              1 of 10346
# 357                              1 of 10346
# 358                              1 of 10346
# 359                              1 of 10346
# 360                              1 of 10346
# 361                              1 of 10346
# 362                              1 of 10346
# 363                              1 of 10346
# 364                              1 of 10346
# 365                              1 of 10346
# 366                              1 of 10346
# 367                              1 of 10346
# 368                              1 of 10346
# 369                              1 of 10346
# 370                              1 of 10346
# 371                              1 of 10346
# 372                              1 of 10346
# 373                              1 of 10346
# 374                              1 of 10346
#
#                                    Unnamed: 2 Unnamed: 4       Prenom  \
# 350  REG  SINEAD   03-01-2023 16:35    000377             REG  SINEAD
# 351            SHOW  TABLES                 6
# 352            SUBTOTAL                 €0.00
# 353         1  GOATS TSD               €11.50
# 354                                     PASTA
# 355                                     1  DU
# 356
# 357
# 358                                     PASTA
# 359                                      2 No
# 360            HOLD BALANCE  _ _ _€_2_5_._4_5
# 361                                NEW ANTRIM
# 362  REG  SINEAD   03-01-2023 16:46    000389             REG  SINEAD
# 363            SHOW  TABLES                 9
# 364            SUBTOTAL                €15.95
# 365                            1  AMERICANO L
# 366
# 367
# 368         1  PATE SALAD              €10.95
# 369         1  SOUP                     €5.50
# 370                                      4 No
# 371            EX VAT@9%               €22.07
# 372            VAT@9%                   €1.98
# 373            _T_O_T_A_L    _ _ _€_2_4_._0_5
# 374            Visa                    €24.05
#
#            Date  Heure Transaction   Prix Total Transaction
# 350  03-01-2023  16:35      000377
# 351
# 352                                  0.00
# 353                                 11.50
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362  03-01-2023  16:46      000389
# 363
# 364                                 15.95
# 365
# 366
# 367
# 368                                 10.95
# 369                                  5.50
# 370
# 371                                 22.07
# 372                                  1.98
# 373                                                    2405
# 374                                 24.05

# %%
df_rua.iloc[400:450]
# Out:
#     CAFE RUA\n\n.\nCASTLEBAR\nCOUNTY MAYO\n  \
# 400                              1 of 10346
# 401                              1 of 10346
# 402                              1 of 10346
# 403                              1 of 10346
# 404                              1 of 10346
# 405                              1 of 10346
# 406                              1 of 10346
# 407                              1 of 10346
# 408                              1 of 10346
# 409                              1 of 10346
# 410                              1 of 10346
# 411                              1 of 10346
# 412                              1 of 10346
# 413                              1 of 10346
# 414                              1 of 10346
# 415                              1 of 10346
# 416                              1 of 10346
# 417                              1 of 10346
# 418                              1 of 10346
# 419                              1 of 10346
# 420                              1 of 10346
# 421                              1 of 10346
# 422                              1 of 10346
# 423                              1 of 10346
# 424                              1 of 10346
# 425                              1 of 10346
# 426                              1 of 10346
# 427                              1 of 10346
# 428                              1 of 10346
# 429                              1 of 10346
# 430                              1 of 10346
# 431                              1 of 10346
# 432                              1 of 10346
# 433                              1 of 10346
# 434                              1 of 10346
# 435                              1 of 10346
# 436                              1 of 10346
# 437                              1 of 10346
# 438                              1 of 10346
# 439                              1 of 10346
# 440                              1 of 10346
# 441                              1 of 10346
# 442                              1 of 10346
# 443                              1 of 10346
# 444                              1 of 10346
# 445                              1 of 10346
# 446                              1 of 10346
# 447                              1 of 10346
# 448                              1 of 10346
# 449                              1 of 10346
#
#                                    Unnamed: 2 Unnamed: 4       Prenom  \
# 400                                    Inline
# 401                                   Receive
# 402
# 403
# 404
# 405         1  2 EGGS + TST             €5.50
# 406                            2 POACHED EGGS
# 407         1  PTN SAUSAGES             €3.00
# 408                                      5 No
# 409            HOLD BALANCE  _ _ _€_2_6_._7_5
# 410                                NEW ANTRIM
# 411  REG  SINEAD   04-01-2023 09:08    000014             REG  SINEAD
# 412                                        NO
# 413
# 414
# 415            HOLD BALANCE  _ _ _€_2_0_._0_0
# 416                                NEW ANTRIM
# 417  REG  SINEAD   04-01-2023 09:36    000024             REG  SINEAD
# 418            SHOW  TABLES                 4
# 419            SUBTOTAL                 €3.50
# 420                                      1 No
# 421                  EX VAT@9%
# 422
# 423
# 424         1  LATTE TA                 €3.50
# 425         1  8oz FLAT WHITE TA        €3.20
# 426                                      4 No
# 427            EX VAT@9%               €12.57
# 428            VAT@9%                   €1.13
# 429            _T_O_T_A_L    _ _ _€_1_3_._7_0
# 430            Visa                    €13.70
# 431
# 432
# 433                                      1 No
# 434            EX VAT@9%                €1.61
# 435            VAT@9%                   €0.14
# 436            _T_O_T_A_L      _ _ _€_1_._7_5
# 437            _C_A_S_H                €10.00
# 438            _C_H_A_N_G_E             €8.25
# 439                                  NEW ANTR
# 440
# 441
# 442            HOLD BALANCE  _ _ _€_3_1_._3_5
# 443                                NEW ANTRIM
# 444  REG  AOIFE    04-01-2023 10:46    000056              REG  AOIFE
# 445            SHOW  TABLES                 3
# 446            SUBTOTAL                €26.75
# 447         1  AMERICANO TA             €2.90
# 448
# 449
#
#            Date  Heure Transaction   Prix Total Transaction
# 400
# 401
# 402
# 403
# 404
# 405                                  5.50
# 406
# 407                                  3.00
# 408
# 409
# 410
# 411  04-01-2023  09:08      000014
# 412
# 413
# 414
# 415
# 416
# 417  04-01-2023  09:36      000024
# 418
# 419                                  3.50
# 420
# 421
# 422
# 423
# 424                                  3.50
# 425                                  3.20
# 426
# 427                                 12.57
# 428                                  1.13
# 429                                                    1370
# 430                                 13.70
# 431
# 432
# 433
# 434                                  1.61
# 435                                  0.14
# 436                                                     175
# 437                                 10.00
# 438                                  8.25
# 439
# 440
# 441
# 442
# 443
# 444  04-01-2023  10:46      000056
# 445
# 446                                 26.75
# 447                                  2.90
# 448
# 449

# %%
df_rua.to_csv('rua_2023_clean_v2.csv', index=False)
